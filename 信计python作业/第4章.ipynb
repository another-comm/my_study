# %% [markdown]
# # 第4章  程序控制结构

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
if 1:
    print (3)
# Out:
# 3

# %%
while 1:
    print (3)
    break
# Out:
# 3

# %% [markdown]
# # 4.1  条件表达式
#
# ## （1）关系运算符：
#   ## Python中的关系运算符可以连续使用，这样不仅可以减少代码量，也比较符合人类的思维方式。
#
#   ## 条件表达式中不允许使用赋值运算符“=”

# %%
a = 3
if a = 3: #条件表达式中不允许使用赋值运算符“=”
    print(3)
# Out:
#   File "<ipython-input-3-066830e910e9>", line 2
#     if a = 3: #条件表达式中不允许使用赋值运算符“=”
#          ^
# SyntaxError: invalid syntax

# %%
print(1<2<3)  #等价于1<2 and 2<3
# Out:
# True

# %%
print(1<2>3)
# Out:
# False

# %%
 print(1<3>2)
# Out:
# True

# %%
a = [1,2,3,4]
for i in a:
    if 2<i<5:
        i = i+2
        print(i)
# Out:
# 5
# 6

# %% [markdown]
# ## （2）逻辑运算符
#
# > ## 逻辑运算符and和or具有短路求值或惰性求值的特点，可能不会对所有表达式进行求值，而是只计算必须计算的表达式的值。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## and 和 or 并不一定会返回True 或 False， 而是最后一个被计算的表达式的值

# %%
3 and 5
# Out:
# 5

# %%
3 or 5
# Out:
# 3

# %%
False and 5
# Out:
# False

# %% [markdown]
# ## 运算符not一定会返回True 或 False

# %%
not 3
# Out:
# False

# %% [markdown]
# # 4.2  选择结构

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4.2.1  单分支选择结构

# %%
if 表达式:
    语句块

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4.2.2  双分支选择结构

# %% [markdown]
# if 表达式:
#     语句块1
# else:
#     语句块2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
chTest = ['1', '2', '3', '4', '5']
if chTest:
    print(chTest)
else:
    print('Empty')
# Out:
# ['1', '2', '3', '4', '5']

# %%
#问题解决：鸡兔同笼。

jitu, tui = map(int, input('请输入鸡兔总数和腿总数：').split())
tu = (tui - jitu*2) / 2
if int(tu) == tu:
    print('鸡：{0},兔：{1}'.format(int(jitu-tu), int(tu)))
else:
    print('数据不正确，无解')
# Out:
# 请输入鸡兔总数和腿总数：4 20
# 鸡：-2,兔：6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(6 if 5<3 else 5)
# Out:
# 5

# %%
b = 6 if 5>13 else 9
b
# Out:
# 9

# %%
import math
import random
x = math.sqrt(9) if 5<3 else random.randint(1,100)
x
# Out:
# 53

# %% [markdown]
# ## 4.2.3  多分支选择结构

# %% [markdown]
# if 表达式1:
#     语句块1
# elif 表达式2:
#     语句块2
# elif 表达式3:
#     语句块3
# else:
#     语句块4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 问题解决：使用多分支选择结构将成绩从百分制变换到等级制。

# %%
def func(score):
    if score > 100 or score < 0:
        return 'wrong score.must between 0 and 100.'
    elif score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    elif score >= 70:
        return 'C'
    elif score >= 60:
        return 'D'
    else:
        return 'E'

# %%
func(86)
# Out:
# 'B'

# %% [markdown]
# ## 4.2.4  选择结构的嵌套

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 问题解决：使用嵌套选择结构将成绩从百分制变换到等级制。

# %%
def func(score):
    degree = 'DCBAAE'
    if score > 100 or score < 0:
        return 'wrong score.must between 0 and 100.'
    else:
        index = (score - 60) // 10
        if index >= 0:
            return degree[index]
        else:
            return degree[-1]

# %% [markdown]
# # 4.3  循环结构

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## for循环与while循环

# %%
#问题解决：使用循环结构遍历并输出列表中的所有元素。
a_list = ['a', 'b', 'mpilgrim', 'z', 'example']
for i, v in enumerate(a_list):
    print('列表的第', i+1, '个元素是：', v)
# Out:
# 列表的第 1 个元素是： a
# 列表的第 2 个元素是： b
# 列表的第 3 个元素是： mpilgrim
# 列表的第 4 个元素是： z
# 列表的第 5 个元素是： example

# %%
#问题解决：输出1~100之间能被7整除但不能同时被5整除的所有整数。

for i in range(1, 101):
    if i%7==0 and i%5!=0:
        print(i)
        #break
# Out:
# 7

# %%
# 问题解决：使用嵌套的循环结构打印九九乘法表。

for i in range(1, 10):
    for j in range(1, i+1):
        print('{0}*{1}={2}'.format(i,j,i*j), end='  ')
    print()                    #打印空行
# Out:
# 1*1=1
# 2*1=2  2*2=4
# 3*1=3  3*2=6  3*3=9
# 4*1=4  4*2=8  4*3=12  4*4=16
# 5*1=5  5*2=10  5*3=15  5*4=20  5*5=25
# 6*1=6  6*2=12  6*3=18  6*4=24  6*5=30  6*6=36
# 7*1=7  7*2=14  7*3=21  7*4=28  7*5=35  7*6=42  7*7=49
# 8*1=8  8*2=16  8*3=24  8*4=32  8*5=40  8*6=48  8*7=56  8*8=64
# 9*1=9  9*2=18  9*3=27  9*4=36  9*5=45  9*6=54  9*7=63  9*8=72  9*9=81

# %%
#问题解决：计算1+2+3+…+99+100的结果。

s = 0
for i in range(1, 101):            #不包括101
    s = s+i
    break
else:
    print(s)   
    
print(s)
# Out:
# 1

# %% [markdown]
# ## 4.3.2  break与continue语句

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 问题解决：计算小于100的最大素数。

for n in range(100, 1, -1):
    for i in range(2, n):
        if n%i == 0:
            break  #跳出内循环
    else:
        print(n)
        break  #跳出外循环

# %%
# 删除上面代码中最后一个break语句，则可以用来输出100以内的所有素数。

for n in range(100, 1, -1):
    for i in range(2, n):
        if n%i == 0:
            break
    else:
        print(n, end=' ')
# Out:
# 97 89 83 79 73 71 67 61 59 53 47 43 41 37 31 29 23 19 17 13 11 7 5 3 2

# %%
 # 警惕continue可能带来的问题：
i = 0
while i<10:
    if i%2==0:
        continue
    print(i)
    i= i+1
    
 # 一直打印0

# %% [markdown]
# ![592eec4d-15c5-409d-a465-2e92c20a3243.png](attachment:592eec4d-15c5-409d-a465-2e92c20a3243.png)

# %%
i=0
while i<10:    
    if i%2==0:
        i = i+1
        continue
    print(i)
    
 # 一直打印1

# %% [markdown]
# ![3cd80a32-bb39-44f3-9d0b-558fa39389ae.png](attachment:3cd80a32-bb39-44f3-9d0b-558fa39389ae.png)

# %%
i=0
while i<10:
    i = i+1
    if i%2==0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10):
    if i%2==0:    
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ![29cae5cd-eff1-42d8-badc-694ed17006ff.png](attachment:29cae5cd-eff1-42d8-badc-694ed17006ff.png)

# %%
for i in range(10):
    if i%2==0: 
        i = i+5
        continue
    print(i)

# %% [markdown]
# ![0d2ca855-9565-4d4f-a615-b71e56c2832a.png](attachment:0d2ca855-9565-4d4f-a615-b71e56c2832a.png)

# %% [markdown]
# # 4.3.3 循环结构的优化

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
digits = (1, 2, 3, 4)
for i in range(1000):
    result = []
    for i in digits:
        i = i*100
        for j in digits:
            j = j*10
            for k in digits:
                result.append(i+j+k)
#result

# %% [markdown]
# ## 不推荐使用“模块名.对象名”的方式来访问。

# %%
import math
from time import time

start = time()
for i in range(100000000):
    math.sin(i)
print(time()-start)

start = time()
# 这种方式可以减少一次查表
loc_sin = math.sin
for i in range(100000000):
    loc_sin(i)
print(time()-start)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4.4  精彩案例赏析

# %% [markdown]
# ## 例4-1  输入若干个成绩，求所有成绩的平均分。每输入一个成绩后询问是否继续输入下一个成绩，回答“yes”就继续输入下一个成绩，回答“no”就停止输入成绩。

# %%
numbers = []                         # 使用列表存放临时数据
while True:
    x = input('请输入一个成绩：')
    try:                             # 异常处理结构
        numbers.append(float(x))
    except:
        print('不是合法成绩')
    while True:
        flag = input('继续输入吗？（yes/no）').lower()
        if flag not in ('yes', 'no'): # 限定用户输入内容必须为yes或no
            noprint('只能输入yes或no')
        else:
            break
    if flag == 'no':
        break

print(sum(numbers)/len(numbers))
# Out:
# 请输入一个成绩：0
# 继续输入吗？（yes/no）no
# 0.0

# %% [markdown]
# ## 示例4-3  编写代码，输出由星号*组成的菱形图案，并且可以灵活控制图案的大小。

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
(' * '*2).center(18)#会让字符串在 18个字符的宽度内居中。
# Out:
# '       *  *       '

# %%
def main(n):
    for i in range(n):
        print((' * '*i).center(n*3))
    for i in range(n, 0, -1):
        print((' * '*i).center(n*3))

main(6)
main(10)
# Out:
#
#         *
#        *  *
#      *  *  *
#     *  *  *  *
#   *  *  *  *  *
#  *  *  *  *  *  *
#   *  *  *  *  *
#     *  *  *  *
#      *  *  *
#        *  *
#         *
#
#               *
#              *  *
#            *  *  *
#           *  *  *  *
#         *  *  *  *  *
#        *  *  *  *  *  *
#      *  *  *  *  *  *  *
#     *  *  *  *  *  *  *  *
#   *  *  *  *  *  *  *  *  *
#  *  *  *  *  *  *  *  *  *  *
#   *  *  *  *  *  *  *  *  *
#     *  *  *  *  *  *  *  *
#      *  *  *  *  *  *  *
#        *  *  *  *  *  *
#         *  *  *  *  *
#           *  *  *  *
#            *  *  *
#              *  *
#               *

# %% [markdown]
# ## 示例4-4  判断一个数是否为素数。

# %%
import math

n = input('Input an integer:')
n = int(n)
m = math.ceil(math.sqrt(n)+1)#向上取整
for i in range(2, m):
    if n%i == 0 and i<n:
        print('No')
        break
else:
    print('Yes')
# Out:
# Input an integer:8
# No

# %% [markdown]
# ## 例4-5  编写程序，计算组合数C(n,i)，即从n个元素中任选i个，有多少种选法。
#
# ## 根据组合数定义，需要计算3个数的阶乘，在很多编程语言中都很难直接使用整型变量表示大数的阶乘结果，虽然Python并不存在这个问题，但是计算大数的阶乘仍需要相当多的时间。本例提供另一种计算方法：以Cni(8,3)为例，按定义式展开如下，对于(5,8]区间的数，分子上出现一次而分母上没出现；(3,5]区间的数在分子、分母上各出现一次；[1,3]区间的数分子上出现一次而分母上出现两次

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def Cni2(n, i):
    if not (isinstance(n,int) and isinstance(i,int) and n>=i):
        print('n and i must be integers and n must be larger than or equal to i.')
        return
    result = 1
    Min, Max = sorted((i,n-i))
    for i in range(n,0,-1):
        if i>Max:
            result *= i
        elif i<=Min:
            result /= i
    return result
print(Cni2(6,2))
# Out:
# 15.0
