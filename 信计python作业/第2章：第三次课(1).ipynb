# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## list()、tuple()、dict()、set()用来把其他类型的数据转换成为列表、元组、字典、集合，或者创建空列表、空元组、空字典和空集合。

# %%
a = [1,2,3]

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
tuple(range(5))
# Out:
# (0, 1, 2, 3, 4)

# %%
s = dict([(1,'a'),(2,'b')])
s
# Out:
# {1: 'a', 2: 'b'}

# %%
s = zip('123','abc')
ds = dict(s)
ds
# Out:
# {'1': 'a', '2': 'b', '3': 'c'}

# %%
s = ['a','b','c']
g = enumerate(s)
dg = dict(g)
dg
# Out:
# {0: 'a', 1: 'b', 2: 'c'}

# %%
a = {1:'ss',2:'ww'}
for i in a:
    print(a[i])
# Out:
# ss
# ww

# %%
a = {1:'ss',2:'ww'}
for i,j in a.items():
    #print(i,j)
    print('{key}:{value}'.format(key = i, value = j))
# Out:
# 1:ss
# 2:ww

# %% [markdown]
# ## ord()和chr()是一对功能相反的函数，ord()用来返回单个字符的Unicode码，而chr()则用来返回Unicode编码对应的字符，str()则直接将其任意类型参数转换为字符串。

# %%
ord('毛')#unicode
# Out:
# 27611

# %%
chr(_)
# Out:
# '毛'

# %%
ord('a'),ord('b')
# Out:
# (97, 98)

# %%
'ab' < 'ba'
# Out:
# True

# %% [markdown]
# ## 2.4.2   最值与求和

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from random import randint
a = [randint(1,100) for i in range(10)]  # 包含10个[1,100]之间随机数的列表
print(a)
print(max(a), min(a), sum(a))            # 最大值、最小值、所有元素之和
sum(a) / len(a)                          # 平均值
# Out:
# [29, 85, 40, 21, 30, 49, 76, 58, 1, 50]
# 85 1 439
# 43.9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
max(['2', '111'])
# Out:
# '2'

# %%
max([2, 111])
# Out:
# 111

# %%
max(['2', 'aaa'], key=len)
# Out:
# 'aaa'

# %%
print(max([1,2,3], default=None))
# Out:
# 3

# %%
print(max([], default='Happy'))   #对空列表求最大值，返回Happy ;default命名参数用来指定最大值不存在时返回的默认值
# Out:
# Happy

# %%
sum([1, 2, 3])
# Out:
# 6

# %%
sum([2**i for i in range(2)])
# Out:
# 3

# %%
ss = [[1,2],[3,4],[3,5]]
max(ss, key = lambda x:x[1])
# Out:
# [3, 5]

# %%
sum([[1,2], [3], [4]], start=[])
# Out:
# [1, 2, 3, 4]

# %%
sum(['a', 'b', 'c'], start='')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-19951b0bff16> in <module>
# ----> 1 sum(['a', 'b', 'c'], start='')
#
# TypeError: sum() can't sum strings [use ''.join(seq) instead]

# %%
'a'+ 'b'+'c'
# Out:
# 'abc'

# %% [markdown]
# ## sum() 不支持字符串相加操作

# %%
#sum(['123','4'],start='')

# %%
'123'+'4'
# Out:
# '1234'

# %%
s = ['123','4']
''.join(s)
# Out:
# '1234'

# %% [markdown]
# ## 2.4.3  基本输入输出
# ![image.png](attachment:image.png)

# %%
x = input('Please input: ')
# Out:
# Please input: [1,2]

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(1,2,3,sep='o',end='\n')
print(1,2,3,sep=';',end='\n')
# Out:
# 1 o2 o3
# 1 ;2 ;3

# %%
print('a', 'b' ,'c',sep='o')
# Out:
# aoboc

# %%
print('a','c','[1,2]')
# Out:
# a c [1,2]

# %%
print('a','c',[1,2])
# Out:
# a c [1, 2]

# %%
print('a''c''[1,2]')
# Out:
# ac[1,2]

# %%
f = open('sample.txt','r+',encoding = 'utf-8' )
for line in f:
    print(line)
# Out:
# 文本文件写入方法

# %%
with open(r'C:\Users\Yawen\Desktop\test.txt', 'a+') as fp:
    print('Python', file=fp)    # 重定向，将内容输出到文件中

# %% [markdown]
# ## 2.4.9  eval()

# %% [markdown]
# ## 内置函数eval()计算并返回字符串或字节码对象source中表达式的值, 参数globals和locals用来指定字符串source中变量的值，如果二者有冲突，以locals为准

# %%
help(eval)
# Out:
# Help on built-in function eval in module builtins:
#
# eval(source, globals=None, locals=None, /)
#     Evaluate the given source in the context of globals and locals.
#
#     The source may be a string representing a Python expression
#     or a code object as returned by compile().
#     The globals must be a dictionary and locals can be any mapping,
#     defaulting to the current globals and locals.
#     If only globals is given, locals defaults to it.

# %%
x = input('Please input: ')
y = eval(x)
sum(y)
# Out:
# Please input: [4,5]
# 9

# %%
eval('111'+'1*2')
# Out:
# 2222

# %%
'111'+'1*2'
# Out:
# '1111*2'

# %%
eval('*'.join(map(str, range(1, 6))))
# Out:
# 120

# %%
eval('a+b+c', {'c':8, 'a':3, 'b':9})
# Out:
# 20

# %%
eval('a+b+c', {'c':8, 'a':3, 'b':9}, {'c':2})
# Out:
# 14

# %%
compile('print(3+5)', 'temp.txt', 'exec')
exec('print(3+5)')
# Out:
# <code object <module> at 0x000002012A393EA0, file "temp.txt", line 1>

# %% [markdown]
# ## eval可以对字符串求值外，还可以执行内置函数compile()编译生成的代码对象

# %%
eval(compile('print(3+5)', 'temp.txt', 'exec'))
# Out:
# 8

# %% [markdown]
# ## 2.4.4  排序与逆序

# %% [markdown]
# ## sorted()对列表、元组、字典、集合或其他可迭代对象进行排序并返回新列表，reversed()对可迭代对象（生成器对象和具有惰性求值特性的zip、map、filter、enumerate等类似对象除外）进行翻转（首尾交换）并返回可迭代的reversed对象

# %%
import random
x = [random.randint(1,100) for i in range(0,10)] #列表推导式
x
# Out:
# [45, 65, 7, 90, 97, 33, 28, 17, 52, 86]

# %%
sorted(x) #返回一个新列表,原来列表保持不变
# Out:
# [7, 17, 28, 33, 45, 52, 65, 86, 90, 97]

# %%
x
# Out:
# [45, 65, 7, 90, 97, 33, 28, 17, 52, 86]

# %%
x.sort()#返回空
x
# Out:
# [7, 17, 28, 33, 45, 52, 65, 86, 90, 97]

# %%
x = list(range(11))
import random
random.shuffle(x) 
x
# Out:
# [7, 9, 4, 0, 5, 10, 2, 6, 1, 8, 3]

# %%
sorted(x, key = lambda y:len(str(y)), reverse=True) #大到小
# Out:
# [10, 7, 9, 4, 0, 5, 2, 6, 1, 8, 3]

# %%
import random
x = [random.randint(1,100) for i in range(0,10)] #列表推导式
x
# Out:
# [89, 47, 1, 6, 39, 82, 65, 59, 17, 9]

# %%
sorted(x, key=str)
# Out:
# [1, 17, 39, 47, 59, 6, 65, 82, 89, 9]

# %%
x = ['aaaa', 'bc', 'd', 'b', 'ba']
sorted(x, key=lambda item: (len(item), item))
# Out:
# ['b', 'd', 'ba', 'bc', 'aaaa']

# %%
y = reversed(x) #注意，sorted不影响原来x 
                # 逆序，返回reversed对象,同样不影响原来x 

list(y)
# Out:
# ['ba', 'b', 'd', 'bc', 'aaaa']

# %%
x
# Out:
# ['aaaa', 'bc', 'd', 'b', 'ba']

# %% [markdown]
# ## 2.4.5  枚举与迭代

# %% [markdown]
# ## enumerate()函数用来枚举可迭代对象中的元素，返回可迭代的enumerate对象，其中每个元素都是包含索引和值的元组。

# %%
list(enumerate('abcd'))
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c'), (3, 'd')]

# %%
list(enumerate('abcd',6))
# Out:
# [(6, 'a'), (7, 'b'), (8, 'c'), (9, 'd')]

# %%
dd = enumerate('abcd')
dd

# %%
(0, 'a') in dd
# Out:
# True

# %%
list(dd)
# Out:
# [(1, 'b'), (2, 'c'), (3, 'd')]

# %%
{'a':97, 'b':98, 'c':99}.items()
# Out:
# dict_items([('a', 97), ('b', 98), ('c', 99)])

# %%
list(enumerate({'a':97, 'b':98, 'c':99}))
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %%
for index, value in enumerate(range(10, 15)):     #枚举range对象中的元素
    print((index, value), end=' ')
# Out:
# (0, 10) (1, 11) (2, 12) (3, 13) (4, 14)

# %% [markdown]
# ## 2.4.6  map()、reduce()、filter()

# %% [markdown]
# ## 内置函数map()把一个函数func依次映射到序列或迭代器对象的每个元素上，并返回一个可迭代的map对象作为结果，map对象中每个元素是原序列中元素经过函数func处理后的结果。

# %%
#help(map)

# %%
list(map(str, range(5)))
# Out:
# ['0', '1', '2', '3', '4']

# %%
def add(x):
    return x+5

list(map(add, range(5)))
# Out:
# [5, 6, 7, 8, 9]

# %%
def add(x,y,z):
    return x+y+z

list(map(add, range(5), range(5,10), range(15,20)))
# Out:
# [20, 23, 26, 29, 32]

# %% [markdown]
# ## 要求实现序列与四字函数的四则运算

# %%
def myfun(x,op,y):
    func = lambda i,j:eval('i'+op+'j')
    return map(func,x,y)

list(myfun(range(5),'+', range(5,10)))
# Out:
# [5, 7, 9, 11, 13]

# %% [markdown]
# ## 标准库functools中的函数reduce()可以将一个接收2个参数的函数以迭代累积的方式从左到右依次作用到一个序列或迭代器对象的所有元素上，并且允许指定一个初始值。
# ![image.png](attachment:image.png)

# %%
from functools import reduce
help (reduce)
#reduce(lambda x, y: x+y, [1, 2, 3, 4, 5])
# Out:
# Help on built-in function reduce in module _functools:
#
# reduce(...)
#     reduce(function, sequence[, initial]) -> value
#
#     Apply a function of two arguments cumulatively to the items of a sequence,
#     from left to right, so as to reduce the sequence to a single value.
#     For example, reduce(lambda x, y: x+y, [1, 2, 3, 4, 5]) calculates
#     ((((1+2)+3)+4)+5).  If initial is present, it is placed before the items
#     of the sequence in the calculation, and serves as a default when the
#     sequence is empty.

# %%
import operator
operator.add(3,5)
# Out:
# 8

# %%
from functools import reduce
reduce(operator.add, [1, 2, 3, 4, 5],4)
# Out:
# 19

# %% [markdown]
# ## 注意列表的相加 ！！！初值的设置

# %%
from functools import reduce
#help (reduce)
reduce(lambda x, y: x+y, [[1, 2], [3], [4, 5]],[])
# Out:
# [1, 2, 3, 4, 5]

# %%
sum([[1, 2], [3], [4, 5]],start=[])
# Out:
# [1, 2, 3, 4, 5]

# %%
sum([1, 2, 3, 4, 5])
# Out:
# 15

# %%
#f = zip('abcd','1234')
f = ['abcdef','5']
from functools import reduce
#help (reduce)
reduce(lambda x, y: x+y, f)
# Out:
# 'abcdef5'

# %%
''.join(f)
# Out:
# 'abcdef5'

# %% [markdown]
# ## 内置函数filter()将一个单参数函数作用到一个序列上，返回该序列中使得该函数返回值为True的那些元素组成的filter对象，如果指定函数为None，则返回序列中等价于True的元素。

# %%
seq = ['foo', 'x41', '?!', '***']
def func(x):
    return x.isalnum() #测试是否为字母或数字
filter(func, seq)

# %%
list(filter(func, seq))
# Out:
# ['foo', 'x41']

# %% [markdown]
# ## zip()函数用来把多个可迭代对象中的元素压缩到一起，返回一个可迭代的zip对象，其中每个元素都是包含原来的多个可迭代对象对应位置上元素的元组，如同拉拉链一样
# ![image.png](attachment:image.png)

# %%
list(zip('123', 'abc', ',.!'))
# Out:
# [('1', 'a', ','), ('2', 'b', '.'), ('3', 'c', '!')]

# %%
list(zip('123', 'abcd'))
# Out:
# [('1', 'a'), ('2', 'b'), ('3', 'c')]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list(range(1, 10, 2))
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# ## 2.5  精彩案例赏析

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = '123'
a = x[0]
b = x[1]
c = x[2]
#print(eval(a),eval(b),eval(c))
eval(a),eval(b),eval(c)
# Out:
# (1, 2, 3)

# %%
x = input('请输入一个三位数：')
a, b, c = map(int, x)
print(a, b, c)
# Out:
# 请输入一个三位数：123
# 1 2 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
x = input('输入两边长及夹角（度）列表格式：')
a, b, theta = map(float, eval(x))
c = math.sqrt(a**2 + b**2 - 2*a*b*math.cos(theta*math.pi/180))
print('c=', c)
# Out:
# 输入两边长及夹角（度）列表格式：[3,4,90]
# c= 5.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = input('x,y,z=')
x, y, z = sorted(map(str, s))
print(x, y, z)
# Out:
# x,y,z=use
# e s u

# %%
set([1,2,3,1,3,4])
# Out:
# {1, 2, 3, 4}

# %%
list(_)
# Out:
# [1, 2, 3, 4]

# %%
def main(lst):
    return list(set(lst))

main([1,2,2,3,4,1])
# Out:
# [1, 2, 3, 4]

# %%
y = sorted(_)
y
# Out:
# [1, 2, 3, 4]
